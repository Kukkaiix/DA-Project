# %% [markdown]
# Change Data to YYYY-MM-DD

# %%
import pandas as pd
import os

# ฟังก์ชันสำหรับการเปลี่ยนรูปแบบวันที่
def change_date_format(input_dir, output_dir):
    # ตรวจสอบว่า output_dir มีอยู่หรือไม่ ถ้าไม่มีก็สร้างใหม่
    os.makedirs(output_dir, exist_ok=True)

    # ลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์ input_dir
    for file_name in os.listdir(input_dir):
        if file_name.endswith('.csv'):
            input_file_path = os.path.join(input_dir, file_name)
            output_file_path = os.path.join(output_dir, file_name)

            # อ่านไฟล์ CSV
            df = pd.read_csv(input_file_path)

            # ตรวจสอบว่า 'Date' คอลัมน์มีอยู่ใน DataFrame หรือไม่
            if 'Date' in df.columns:
                # แปลงคอลัมน์ 'Date' เป็น datetime object โดยใช้ format '%y-%m-%d' และแปลงให้เป็นรูปแบบ 'YYYY-MM-DD'
                df['Date'] = pd.to_datetime(df['Date'], format='%y-%m-%d').dt.strftime('%Y-%m-%d')

                # บันทึกไฟล์ที่มีการเปลี่ยนแปลงลงในโฟลเดอร์ output_dir
                df.to_csv(output_file_path, index=False, encoding='utf-8-sig')
                print(f"✅ {file_name} processed and saved to {output_file_path}")
            else:
                print(f"⚠️ 'Date' column not found in {file_name}, skipping this file.")

# กำหนดที่อยู่ของโฟลเดอร์ข้อมูล
input_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Connect the provice/Selected_Province"
output_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year"

# เรียกใช้ฟังก์ชัน
change_date_format(input_dir, output_dir)
# Out:
# ✅ selected_processed_20221002.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221002.csv
# ✅ selected_processed_20221016.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221016.csv
# ✅ selected_processed_20220308.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220308.csv
# ✅ selected_processed_20220320.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220320.csv
# ✅ selected_processed_20231013.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231013.csv
# ✅ selected_processed_20230319.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230319.csv
# ✅ selected_processed_20231007.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231007.csv
# ✅ selected_processed_20230331.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230331.csv
# ✅ selected_processed_20230325.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230325.csv
# ✅ selected_processed_20241127.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241127.csv
# ✅ selected_processed_20241126.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241126.csv
# ✅ selected_processed_20230324.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230324.csv
# ✅ selected_processed_20230330.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230330.csv
# ✅ selected_processed_20231006.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231006.csv
# ✅ selected_processed_20230318.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230318.csv
# ✅ selected_processed_20231012.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231012.csv
# ✅ selected_processed_20220321.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220321.csv
# ✅ selected_processed_20220309.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220309.csv
# ✅ selected_processed_20221017.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221017.csv
# ✅ selected_processed_20221003.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221003.csv
# ✅ selected_processed_20221015.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221015.csv
# ✅ selected_processed_20221001.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221001.csv
# ✅ selected_processed_20221029.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221029.csv
# ✅ selected_processed_20220323.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220323.csv
# ✅ selected_processed_20231004.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231004.csv
# ✅ selected_processed_20231010.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231010.csv
# ✅ selected_processed_20230326.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230326.csv
# ✅ selected_processed_20241130.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241130.csv
# ✅ selected_processed_20241124.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241124.csv
# ✅ selected_processed_20241118.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241118.csv
# ✅ selected_processed_20241119.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241119.csv
# ✅ selected_processed_20241125.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241125.csv
# ✅ selected_processed_20230327.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230327.csv
# ✅ selected_processed_20231011.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231011.csv
# ✅ selected_processed_20231005.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231005.csv
# ✅ selected_processed_20220322.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220322.csv
# ✅ selected_processed_20221028.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221028.csv
# ✅ selected_processed_20221014.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221014.csv
# ✅ selected_processed_20220326.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220326.csv
# ✅ selected_processed_20221010.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221010.csv
# ✅ selected_processed_20221004.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221004.csv
# ✅ selected_processed_20230323.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230323.csv
# ✅ selected_processed_20231029.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231029.csv
# ✅ selected_processed_20231001.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231001.csv
# ✅ selected_processed_20231015.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231015.csv
# ✅ selected_processed_20241109.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241109.csv
# ✅ selected_processed_20241121.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241121.csv
# ✅ selected_processed_20241120.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241120.csv
# ✅ selected_processed_20241108.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241108.csv
# ✅ selected_processed_20231014.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231014.csv
# ✅ selected_processed_20231028.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231028.csv
# ✅ selected_processed_20230322.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230322.csv
# ✅ selected_processed_20221005.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221005.csv
# ✅ selected_processed_20221011.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221011.csv
# ✅ selected_processed_20220327.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220327.csv
# ✅ selected_processed_20220325.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220325.csv
# ✅ selected_processed_20220331.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220331.csv
# ✅ selected_processed_20221007.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221007.csv
# ✅ selected_processed_20220319.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220319.csv
# ✅ selected_processed_20221013.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221013.csv
# ✅ selected_processed_20230320.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230320.csv
# ✅ selected_processed_20230308.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230308.csv
# ✅ selected_processed_20231016.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231016.csv
# ✅ selected_processed_20231002.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231002.csv
# ✅ selected_processed_20241122.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241122.csv
# ✅ selected_processed_20241123.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241123.csv
# ✅ selected_processed_20231003.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231003.csv
# ✅ selected_processed_20231017.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231017.csv
# ✅ selected_processed_20230309.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230309.csv
# ✅ selected_processed_20230321.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230321.csv
# ✅ selected_processed_20221012.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221012.csv
# ✅ selected_processed_20220318.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220318.csv
# ✅ selected_processed_20221006.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221006.csv
# ✅ selected_processed_20220330.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220330.csv
# ✅ selected_processed_20220324.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220324.csv
# ✅ selected_processed_20241030.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241030.csv
# ✅ selected_processed_20241024.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241024.csv
# ✅ selected_processed_20240312.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240312.csv
# ✅ selected_processed_20240306.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240306.csv
# ✅ selected_processed_20241018.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241018.csv
# ✅ selected_processed_20231104.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231104.csv
# ✅ selected_processed_20231110.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231110.csv
# ✅ selected_processed_20221115.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221115.csv
# ✅ selected_processed_20221101.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221101.csv
# ✅ selected_processed_20221129.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221129.csv
# ✅ selected_processed_20221128.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221128.csv
# ✅ selected_processed_20221114.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221114.csv
# ✅ selected_processed_20231111.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231111.csv
# ✅ selected_processed_20231105.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231105.csv
# ✅ selected_processed_20241019.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241019.csv
# ✅ selected_processed_20240307.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240307.csv
# ✅ selected_processed_20240313.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240313.csv
# ✅ selected_processed_20241025.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241025.csv
# ✅ selected_processed_20241031.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241031.csv
# ✅ selected_processed_20241027.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241027.csv
# ✅ selected_processed_20240305.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240305.csv
# ✅ selected_processed_20240311.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240311.csv
# ✅ selected_processed_20231113.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231113.csv
# ✅ selected_processed_20231107.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231107.csv
# ✅ selected_processed_20221102.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221102.csv
# ✅ selected_processed_20221116.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221116.csv
# ✅ selected_processed_20221117.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221117.csv
# ✅ selected_processed_20221103.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221103.csv
# ✅ selected_processed_20231106.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231106.csv
# ✅ selected_processed_20231112.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231112.csv
# ✅ selected_processed_20240310.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240310.csv
# ✅ selected_processed_20240304.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240304.csv
# ✅ selected_processed_20241026.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241026.csv
# ✅ selected_processed_20240314.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240314.csv
# ✅ selected_processed_20241022.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241022.csv
# ✅ selected_processed_20240328.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240328.csv
# ✅ selected_processed_20231116.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231116.csv
# ✅ selected_processed_20231102.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231102.csv
# ✅ selected_processed_20221107.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221107.csv
# ✅ selected_processed_20221113.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221113.csv
# ✅ selected_processed_20221112.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221112.csv
# ✅ selected_processed_20221106.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221106.csv
# ✅ selected_processed_20231103.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231103.csv
# ✅ selected_processed_20231117.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231117.csv
# ✅ selected_processed_20240329.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240329.csv
# ✅ selected_processed_20241023.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241023.csv
# ✅ selected_processed_20240315.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240315.csv
# ✅ selected_processed_20240301.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240301.csv
# ✅ selected_processed_20240317.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240317.csv
# ✅ selected_processed_20241009.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241009.csv
# ✅ selected_processed_20240303.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240303.csv
# ✅ selected_processed_20241021.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241021.csv
# ✅ selected_processed_20231129.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231129.csv
# ✅ selected_processed_20231101.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231101.csv
# ✅ selected_processed_20231115.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231115.csv
# ✅ selected_processed_20221110.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221110.csv
# ✅ selected_processed_20221104.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221104.csv
# ✅ selected_processed_20221105.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221105.csv
# ✅ selected_processed_20221111.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221111.csv
# ✅ selected_processed_20231114.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231114.csv
# ✅ selected_processed_20231128.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231128.csv
# ✅ selected_processed_20241020.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241020.csv
# ✅ selected_processed_20240302.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240302.csv
# ✅ selected_processed_20241008.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241008.csv
# ✅ selected_processed_20240316.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240316.csv
# ✅ selected_processed_20241011.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241011.csv
# ✅ selected_processed_20241005.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241005.csv
# ✅ selected_processed_20240327.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240327.csv
# ✅ selected_processed_20231125.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231125.csv
# ✅ selected_processed_20231119.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231119.csv
# ✅ selected_processed_20221120.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221120.csv
# ✅ selected_processed_20221108.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221108.csv
# ✅ selected_processed_20221109.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221109.csv
# ✅ selected_processed_20221121.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221121.csv
# ✅ selected_processed_20231118.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231118.csv
# ✅ selected_processed_20231130.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231130.csv
# ✅ selected_processed_20231124.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231124.csv
# ✅ selected_processed_20240326.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240326.csv
# ✅ selected_processed_20241004.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241004.csv
# ✅ selected_processed_20241010.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241010.csv
# ✅ selected_processed_20240318.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240318.csv
# ✅ selected_processed_20241006.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241006.csv
# ✅ selected_processed_20241012.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241012.csv
# ✅ selected_processed_20240324.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240324.csv
# ✅ selected_processed_20240330.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240330.csv
# ✅ selected_processed_20231126.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231126.csv
# ✅ selected_processed_20221123.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221123.csv
# ✅ selected_processed_20221122.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221122.csv
# ✅ selected_processed_20231127.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231127.csv
# ✅ selected_processed_20240331.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240331.csv
# ✅ selected_processed_20240325.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240325.csv
# ✅ selected_processed_20241013.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241013.csv
# ✅ selected_processed_20241007.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241007.csv
# ✅ selected_processed_20240319.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240319.csv
# ✅ selected_processed_20240321.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240321.csv
# ✅ selected_processed_20241003.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241003.csv
# ✅ selected_processed_20240309.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240309.csv
# ✅ selected_processed_20241017.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241017.csv
# ✅ selected_processed_20231123.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231123.csv
# ✅ selected_processed_20221126.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221126.csv
# ✅ selected_processed_20221127.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221127.csv
# ✅ selected_processed_20231122.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231122.csv
# ✅ selected_processed_20241016.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241016.csv
# ✅ selected_processed_20240308.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240308.csv
# ✅ selected_processed_20241002.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241002.csv
# ✅ selected_processed_20240320.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240320.csv
# ✅ selected_processed_20241028.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241028.csv
# ✅ selected_processed_20240322.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240322.csv
# ✅ selected_processed_20241014.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241014.csv
# ✅ selected_processed_20231108.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231108.csv
# ✅ selected_processed_20231120.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231120.csv
# ✅ selected_processed_20221119.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221119.csv
# ✅ selected_processed_20221125.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221125.csv
# ✅ selected_processed_20221124.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221124.csv
# ✅ selected_processed_20221130.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221130.csv
# ✅ selected_processed_20221118.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221118.csv
# ✅ selected_processed_20231121.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231121.csv
# ✅ selected_processed_20231109.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231109.csv
# ✅ selected_processed_20241001.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241001.csv
# ✅ selected_processed_20241015.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241015.csv
# ✅ selected_processed_20240323.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20240323.csv
# ✅ selected_processed_20241029.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241029.csv
# ✅ selected_processed_20221023.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221023.csv
# ✅ selected_processed_20220329.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220329.csv
# ✅ selected_processed_20220301.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220301.csv
# ✅ selected_processed_20220315.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220315.csv
# ✅ selected_processed_20231026.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231026.csv
# ✅ selected_processed_20230310.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230310.csv
# ✅ selected_processed_20230304.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230304.csv
# ✅ selected_processed_20241106.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241106.csv
# ✅ selected_processed_20241112.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241112.csv
# ✅ selected_processed_20241113.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241113.csv
# ✅ selected_processed_20241107.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241107.csv
# ✅ selected_processed_20230305.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230305.csv
# ✅ selected_processed_20230311.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230311.csv
# ✅ selected_processed_20231027.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231027.csv
# ✅ selected_processed_20220314.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220314.csv
# ✅ selected_processed_20220328.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220328.csv
# ✅ selected_processed_20221022.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221022.csv
# ✅ selected_processed_20221020.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221020.csv
# ✅ selected_processed_20221008.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221008.csv
# ✅ selected_processed_20220316.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220316.csv
# ✅ selected_processed_20220302.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220302.csv
# ✅ selected_processed_20231025.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231025.csv
# ✅ selected_processed_20231031.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231031.csv
# ✅ selected_processed_20230307.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230307.csv
# ✅ selected_processed_20231019.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231019.csv
# ✅ selected_processed_20230313.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230313.csv
# ✅ selected_processed_20241111.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241111.csv
# ✅ selected_processed_20241105.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241105.csv
# ✅ selected_processed_20241104.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241104.csv
# ✅ selected_processed_20241110.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241110.csv
# ✅ selected_processed_20230312.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230312.csv
# ✅ selected_processed_20231018.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231018.csv
# ✅ selected_processed_20230306.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230306.csv
# ✅ selected_processed_20231030.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231030.csv
# ✅ selected_processed_20231024.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231024.csv
# ✅ selected_processed_20220303.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220303.csv
# ✅ selected_processed_20220317.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220317.csv
# ✅ selected_processed_20221009.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221009.csv
# ✅ selected_processed_20221021.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221021.csv
# ✅ selected_processed_20220313.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220313.csv
# ✅ selected_processed_20221019.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221019.csv
# ✅ selected_processed_20220307.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220307.csv
# ✅ selected_processed_20221031.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221031.csv
# ✅ selected_processed_20221025.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221025.csv
# ✅ selected_processed_20230302.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230302.csv
# ✅ selected_processed_20230316.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230316.csv
# ✅ selected_processed_20231008.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231008.csv
# ✅ selected_processed_20231020.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231020.csv
# ✅ selected_processed_20241128.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241128.csv
# ✅ selected_processed_20241114.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241114.csv
# ✅ selected_processed_20241101.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241101.csv
# ✅ selected_processed_20241115.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241115.csv
# ✅ selected_processed_20241129.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241129.csv
# ✅ selected_processed_20231021.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231021.csv
# ✅ selected_processed_20231009.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231009.csv
# ✅ selected_processed_20230317.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230317.csv
# ✅ selected_processed_20230303.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230303.csv
# ✅ selected_processed_20221024.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221024.csv
# ✅ selected_processed_20221030.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221030.csv
# ✅ selected_processed_20220306.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220306.csv
# ✅ selected_processed_20221018.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221018.csv
# ✅ selected_processed_20220312.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220312.csv
# ✅ selected_processed_20220304.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220304.csv
# ✅ selected_processed_20220310.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220310.csv
# ✅ selected_processed_20221026.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221026.csv
# ✅ selected_processed_20230315.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230315.csv
# ✅ selected_processed_20230301.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230301.csv
# ✅ selected_processed_20230329.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230329.csv
# ✅ selected_processed_20231023.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231023.csv
# ✅ selected_processed_20241103.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241103.csv
# ✅ selected_processed_20241117.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241117.csv
# ✅ selected_processed_20241116.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241116.csv
# ✅ selected_processed_20241102.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20241102.csv
# ✅ selected_processed_20231022.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20231022.csv
# ✅ selected_processed_20230328.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230328.csv
# ✅ selected_processed_20230314.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20230314.csv
# ✅ selected_processed_20221027.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20221027.csv
# ✅ selected_processed_20220311.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220311.csv
# ✅ selected_processed_20220305.csv processed and saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year/selected_processed_20220305.csv

# %% [markdown]
# combine 2024 file

# %%
import pandas as pd
import os

# ฟังก์ชันสำหรับการรวมไฟล์ CSV
def combine_files(input_dir, output_file):
    # สร้าง DataFrame ว่างๆ สำหรับการรวมข้อมูล
    combined_df = pd.DataFrame()

    # ลูปผ่านไฟล์ทั้งหมดในโฟลเดอร์
    for file_name in os.listdir(input_dir):
        if file_name.endswith('.csv'):
            input_file_path = os.path.join(input_dir, file_name)

            try:
                # อ่านไฟล์ CSV
                df = pd.read_csv(input_file_path)

                # ตรวจสอบว่า Date คอลัมน์มีอยู่หรือไม่
                if 'Date' not in df.columns:
                    print(f"⚠️ Missing 'Date' column in {file_name}. Skipping this file.")
                    continue

                # รวมข้อมูลเข้าไปใน combined_df
                combined_df = pd.concat([combined_df, df], ignore_index=True)

            except Exception as e:
                # ถ้ามีข้อผิดพลาดในการอ่านไฟล์ให้ปริ้นชื่อไฟล์ที่มีปัญหา
                print(f"⚠️ Error reading {file_name}: {e}")
    
    # บันทึกข้อมูลรวมทั้งหมดลงในไฟล์ output
    if not combined_df.empty:
        combined_df.to_csv(output_file, index=False, encoding='utf-8-sig')
        print(f"✅ Combined data saved to {output_file}")
    else:
        print("⚠️ No valid data to combine.")

# กำหนดที่อยู่ของโฟลเดอร์ข้อมูล
input_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year_2024"
output_file = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/combined_2024.csv"

# เรียกใช้ฟังก์ชัน
combine_files(input_dir, output_file)
# Out:
# ✅ Combined data saved to /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/combined_2024.csv

# %%
import pandas as pd
import os

# input และ output folder
input_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year_2022"
output_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022"

# ถ้าไม่มีโฟลเดอร์ output ให้สร้างใหม่
os.makedirs(output_dir, exist_ok=True)

# loop ทุกไฟล์ในโฟลเดอร์
for file_name in os.listdir(input_dir):
    if file_name.endswith(".csv"):
        input_file = os.path.join(input_dir, file_name)
        output_file = os.path.join(output_dir, f"cleaned_{file_name}")

        try:
            # อ่านไฟล์
            df = pd.read_csv(input_file)

            # 1. แปลงชนิดข้อมูล
            df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
            df['speed_kmh'] = pd.to_numeric(df['speed_kmh'], errors='coerce')

            # 2. ลบแถวที่ไม่มี Date หรือ Province
            df = df.dropna(subset=['Date', 'Province_en'])

            # 3. ลบข้อมูลซ้ำ
            df = df.drop_duplicates()

            # 4. Clean ค่า speed_kmh (ไม่เอาค่าติดลบ และถ้าเกิน 200 ถือว่าผิดปกติ)
            df = df[(df['speed_kmh'] >= 0) & (df['speed_kmh'] <= 200)]

            # 5. Strip ช่องว่างและทำให้ชื่อจังหวัดเป็น Title Case
            df['Province_en'] = df['Province_en'].str.strip().str.title()

            # บันทึกไฟล์ที่ clean แล้ว
            df.to_csv(output_file, index=False, encoding="utf-8-sig")
            print(f"✅ Cleaned and saved: {output_file}")

        except Exception as e:
            print(f"⚠️ Error processing {file_name}: {e}")
# Out:
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221002.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221016.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220308.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220320.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220321.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220309.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221017.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221003.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221015.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221001.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221029.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220323.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220322.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221028.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221014.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220326.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221010.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221004.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221005.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221011.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220327.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220325.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220331.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221007.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220319.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221013.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221012.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220318.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221006.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220330.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220324.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221115.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221101.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221129.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221128.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221114.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221102.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221116.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221117.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221103.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221107.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221113.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221112.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221106.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221110.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221104.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221105.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221111.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221120.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221108.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221109.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221121.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221123.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221122.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221126.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221127.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221119.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221125.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221124.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221130.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221118.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221023.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220329.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220301.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220315.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220314.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220328.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221022.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221020.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221008.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220316.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220302.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220303.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220317.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221009.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221021.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220313.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221019.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220307.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221031.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221025.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221024.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221030.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220306.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221018.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220312.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220304.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220310.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221026.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20221027.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220311.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2022/cleaned_selected_processed_20220305.csv

# %%
import pandas as pd
import os

# input และ output folder
input_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year_2023"
output_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023"

# ถ้าไม่มีโฟลเดอร์ output ให้สร้างใหม่
os.makedirs(output_dir, exist_ok=True)

# loop ทุกไฟล์ในโฟลเดอร์
for file_name in os.listdir(input_dir):
    if file_name.endswith(".csv"):
        input_file = os.path.join(input_dir, file_name)
        output_file = os.path.join(output_dir, f"cleaned_{file_name}")

        try:
            # อ่านไฟล์
            df = pd.read_csv(input_file)

            # 1. แปลงชนิดข้อมูล
            df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
            df['speed_kmh'] = pd.to_numeric(df['speed_kmh'], errors='coerce')

            # 2. ลบแถวที่ไม่มี Date หรือ Province
            df = df.dropna(subset=['Date', 'Province_en'])

            # 3. ลบข้อมูลซ้ำ
            df = df.drop_duplicates()

            # 4. Clean ค่า speed_kmh (ไม่เอาค่าติดลบ และถ้าเกิน 200 ถือว่าผิดปกติ)
            df = df[(df['speed_kmh'] >= 0) & (df['speed_kmh'] <= 200)]

            # 5. Strip ช่องว่างและทำให้ชื่อจังหวัดเป็น Title Case
            df['Province_en'] = df['Province_en'].str.strip().str.title()

            # บันทึกไฟล์ที่ clean แล้ว
            df.to_csv(output_file, index=False, encoding="utf-8-sig")
            print(f"✅ Cleaned and saved: {output_file}")

        except Exception as e:
            print(f"⚠️ Error processing {file_name}: {e}")
# Out:
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231013.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230319.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231007.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230331.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230325.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230324.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230330.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231006.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230318.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231012.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231004.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231010.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230326.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230327.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231011.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231005.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230323.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231029.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231001.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231015.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231014.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231028.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230322.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230320.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230308.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231016.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231002.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231003.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231017.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230309.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230321.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231104.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231110.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231111.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231105.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231113.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231107.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231106.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231112.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231116.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231102.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231103.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231117.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231129.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231101.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231115.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231114.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231128.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231125.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231119.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231118.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231130.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231124.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231126.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231127.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231123.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231122.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231108.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231120.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231121.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231109.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231026.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230310.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230304.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230305.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230311.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231027.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231025.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231031.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230307.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231019.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230313.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230312.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231018.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230306.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231030.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231024.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230302.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230316.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231008.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231020.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231021.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231009.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230317.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230303.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230315.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230301.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230329.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231023.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20231022.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230328.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2023/cleaned_selected_processed_20230314.csv

# %%
import pandas as pd
import os

# input และ output folder
input_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/rewrite_year_2024"
output_dir = "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024"

# ถ้าไม่มีโฟลเดอร์ output ให้สร้างใหม่
os.makedirs(output_dir, exist_ok=True)

# loop ทุกไฟล์ในโฟลเดอร์
for file_name in os.listdir(input_dir):
    if file_name.endswith(".csv"):
        input_file = os.path.join(input_dir, file_name)
        output_file = os.path.join(output_dir, f"cleaned_{file_name}")

        try:
            # อ่านไฟล์
            df = pd.read_csv(input_file)

            # 1. แปลงชนิดข้อมูล
            df['Date'] = pd.to_datetime(df['Date'], errors='coerce')
            df['speed_kmh'] = pd.to_numeric(df['speed_kmh'], errors='coerce')

            # 2. ลบแถวที่ไม่มี Date หรือ Province
            df = df.dropna(subset=['Date', 'Province_en'])

            # 3. ลบข้อมูลซ้ำ
            df = df.drop_duplicates()

            # 4. Clean ค่า speed_kmh (ไม่เอาค่าติดลบ และถ้าเกิน 200 ถือว่าผิดปกติ)
            df = df[(df['speed_kmh'] >= 0) & (df['speed_kmh'] <= 200)]

            # 5. Strip ช่องว่างและทำให้ชื่อจังหวัดเป็น Title Case
            df['Province_en'] = df['Province_en'].str.strip().str.title()

            # บันทึกไฟล์ที่ clean แล้ว
            df.to_csv(output_file, index=False, encoding="utf-8-sig")
            print(f"✅ Cleaned and saved: {output_file}")

        except Exception as e:
            print(f"⚠️ Error processing {file_name}: {e}")
# Out:
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241127.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241126.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241130.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241124.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241118.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241119.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241125.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241109.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241121.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241120.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241108.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241122.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241123.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241030.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241024.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240312.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240306.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241018.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241019.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240307.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240313.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241025.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241031.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241027.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240305.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240311.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240310.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240304.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241026.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240314.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241022.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240328.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240329.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241023.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240315.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240301.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240317.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241009.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240303.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241021.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241020.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240302.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241008.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240316.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241011.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241005.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240327.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240326.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241004.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241010.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240318.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241006.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241012.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240324.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240330.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240331.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240325.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241013.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241007.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240319.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240321.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241003.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240309.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241017.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241016.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240308.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241002.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240320.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241028.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240322.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241014.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241001.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241015.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20240323.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241029.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241106.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241112.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241113.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241107.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241111.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241105.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241104.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241110.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241128.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241114.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241101.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241115.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241129.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241103.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241117.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241116.csv
# ✅ Cleaned and saved: /Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Year_Sep/cleaned_2024/cleaned_selected_processed_20241102.csv

# %% [markdown]
# Extra Part

# %%
import pandas as pd

# Load the CSV file
file_path = '/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Processed_traffic_jam_index(Final)/road_combined_2022.csv'
data = pd.read_csv(file_path)

# Filter the data where speed_kmh is not equal to 0
filtered_data = data[data['speed_kmh'] != 0]

# Display rows 5 to 10 as DataFrame
filtered_data_subset = filtered_data.iloc[5:11]  # Get rows 5 to 10

# Show the resulting DataFrame
print(filtered_data_subset)
# Out:
#           Date  speed_kmh    Province_en  Traffic_jam_index
# 12  2022-03-05         50        Bangkok           0.255668
# 13  2022-03-05         45   Samut Sakhon           0.186708
# 14  2022-03-05         83   Pathum Thani           0.185225
# 15  2022-03-05         20        Bangkok           0.255668
# 17  2022-03-05         25  Nakhon Pathom           0.203593
# 18  2022-03-05         43   Pathum Thani           0.185225
