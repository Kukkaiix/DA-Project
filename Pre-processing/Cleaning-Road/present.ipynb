# %%
import os
import pandas as pd
from glob import glob

# 🗂 Define folders
folders = [
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202203/PROBE-202203",
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202210/PROBE-202210",
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202211/PROBE-202211"
]

overview = []

for folder in folders:
    csv_files = glob(os.path.join(folder, "*.csv"))
    total_rows = 0
    total_cols = 0
    total_missing = 0
    invalid_speed = 0       # เปลี่ยนชื่อคอลัมน์นี้แทน Negative/Over speed
    gps_invalid = 0         # เปลี่ยนจาก GPS Valid → GPS Invalid
    invalid_dates = 0
    
    for file in csv_files:
        try:
            df = pd.read_csv(file)
            
            # Count total
            total_rows += len(df)
            total_cols = max(total_cols, len(df.columns))
            
            # Missing values
            total_missing += df.isna().sum().sum()
            
            # Invalid Speed (negative or over 200 km/h)
            if 'speed_kmh' in df.columns:
                invalid_speed += len(df[(df['speed_kmh'] < 0) | (df['speed_kmh'] > 200)])
            
            # GPS Invalid (gps_valid == 0)
            if 'gps_valid' in df.columns:
                gps_invalid += len(df[df['gps_valid'] == 0])
            
            # Invalid timestamp (NaN or unreadable)
            if 'timestamp' in df.columns:
                invalid_dates += df['timestamp'].isna().sum()
                
        except Exception as e:
            print(f"Error reading {file}: {e}")
    
    total_cells = total_rows * total_cols
    missing_percent = (total_missing / total_cells * 100) if total_cells > 0 else 0
    
    overview.append({
        "Year": os.path.basename(folder),
        "Total Files": len(csv_files),
        "Total Rows": total_rows,
        "Total Columns": total_cols,
        "Missing Values": total_missing,
        "Missing Values Percentage": round(missing_percent, 2),
        "Invalid Speed": invalid_speed,     # ใช้ชื่อใหม่
        "GPS Invalid": gps_invalid,         # ใช้ชื่อใหม่
        "Invalid Dates": invalid_dates
    })

# 📊 Create overview table
df_overview = pd.DataFrame(overview)
df_overview
# Out:
#            Year  Total Files  Total Rows  Total Columns  Missing Values  \
# 0  PROBE-202203           31    59003078              9               0
# 1  PROBE-202210           31    64020936              9               0
# 2  PROBE-202211           30    62335872              9               0
#
#    Missing Values Percentage  Invalid Speed  GPS Invalid  Invalid Dates
# 0                        0.0            153        99024              0
# 1                        0.0            358       132532              0
# 2                        0.0            229       142791              0

# %%
import os
import pandas as pd
from glob import glob

# 🗂 Define folders
folders = [
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202303/PROBE-202303",
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202310/PROBE-202310",
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202311/PROBE-202311"
]

overview = []

for folder in folders:
    csv_files = glob(os.path.join(folder, "*.csv"))
    total_rows = 0
    total_cols = 0
    total_missing = 0
    invalid_speed = 0       # เปลี่ยนชื่อคอลัมน์นี้แทน Negative/Over speed
    gps_invalid = 0         # เปลี่ยนจาก GPS Valid → GPS Invalid
    invalid_dates = 0
    
    for file in csv_files:
        try:
            df = pd.read_csv(file)
            
            # Count total
            total_rows += len(df)
            total_cols = max(total_cols, len(df.columns))
            
            # Missing values
            total_missing += df.isna().sum().sum()
            
            # Invalid Speed (negative or over 200 km/h)
            if 'speed_kmh' in df.columns:
                invalid_speed += len(df[(df['speed_kmh'] < 0) | (df['speed_kmh'] > 200)])
            
            # GPS Invalid (gps_valid == 0)
            if 'gps_valid' in df.columns:
                gps_invalid += len(df[df['gps_valid'] == 0])
            
            # Invalid timestamp (NaN or unreadable)
            if 'timestamp' in df.columns:
                invalid_dates += df['timestamp'].isna().sum()
                
        except Exception as e:
            print(f"Error reading {file}: {e}")
    
    total_cells = total_rows * total_cols
    missing_percent = (total_missing / total_cells * 100) if total_cells > 0 else 0
    
    overview.append({
        "Year": os.path.basename(folder),
        "Total Files": len(csv_files),
        "Total Rows": total_rows,
        "Total Columns": total_cols,
        "Missing Values": total_missing,
        "Missing Values Percentage": round(missing_percent, 2),
        "Invalid Speed": invalid_speed,     # ใช้ชื่อใหม่
        "GPS Invalid": gps_invalid,         # ใช้ชื่อใหม่
        "Invalid Dates": invalid_dates
    })

# 📊 Create overview table
df_overview = pd.DataFrame(overview)
df_overview
# Out:
#            Year  Total Files  Total Rows  Total Columns  Missing Values  \
# 0  PROBE-202303           31    62378275              9               0
# 1  PROBE-202310           31    58815204              9               0
# 2  PROBE-202311           30    59013667              9               0
#
#    Missing Values Percentage  Invalid Speed  GPS Invalid  Invalid Dates
# 0                        0.0            105       107298              0
# 1                        0.0              0          448              0
# 2                        0.0              0            0              0

# %%
import os
import pandas as pd
from glob import glob

# 🗂 Define folders
folders = [
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202403/PROBE-202403",
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202410/PROBE-202410",
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Extracted_bz2 (1)/PROBE-202411/PROBE-202411"
]

overview = []

for folder in folders:
    csv_files = glob(os.path.join(folder, "*.csv"))
    total_rows = 0
    total_cols = 0
    total_missing = 0
    invalid_speed = 0       # เปลี่ยนชื่อคอลัมน์นี้แทน Negative/Over speed
    gps_invalid = 0         # เปลี่ยนจาก GPS Valid → GPS Invalid
    invalid_dates = 0
    
    for file in csv_files:
        try:
            df = pd.read_csv(file)
            
            # Count total
            total_rows += len(df)
            total_cols = max(total_cols, len(df.columns))
            
            # Missing values
            total_missing += df.isna().sum().sum()
            
            # Invalid Speed (negative or over 200 km/h)
            if 'speed_kmh' in df.columns:
                invalid_speed += len(df[(df['speed_kmh'] < 0) | (df['speed_kmh'] > 200)])
            
            # GPS Invalid (gps_valid == 0)
            if 'gps_valid' in df.columns:
                gps_invalid += len(df[df['gps_valid'] == 0])
            
            # Invalid timestamp (NaN or unreadable)
            if 'timestamp' in df.columns:
                invalid_dates += df['timestamp'].isna().sum()
                
        except Exception as e:
            print(f"Error reading {file}: {e}")
    
    total_cells = total_rows * total_cols
    missing_percent = (total_missing / total_cells * 100) if total_cells > 0 else 0
    
    overview.append({
        "Year": os.path.basename(folder),
        "Total Files": len(csv_files),
        "Total Rows": total_rows,
        "Total Columns": total_cols,
        "Missing Values": total_missing,
        "Missing Values Percentage": round(missing_percent, 2),
        "Invalid Speed": invalid_speed,     # ใช้ชื่อใหม่
        "GPS Invalid": gps_invalid,         # ใช้ชื่อใหม่
        "Invalid Dates": invalid_dates
    })

# 📊 Create overview table
df_overview = pd.DataFrame(overview)
df_overview
# Out:
#            Year  Total Files  Total Rows  Total Columns  Missing Values  \
# 0  PROBE-202403           31    60837004              9               0
# 1  PROBE-202410           31    56317826              9               0
# 2  PROBE-202411           30    55629594              9               0
#
#    Missing Values Percentage  Invalid Speed  GPS Invalid  Invalid Dates
# 0                        0.0              0          135              0
# 1                        0.0             72       140593              0
# 2                        0.0             86       141954              0

# %%
import pandas as pd

# File paths (from the files you provided)
files = [
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Processed_traffic_jam_index(Final)/road_combined_2022.csv",
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Processed_traffic_jam_index(Final)/road_combined_2023.csv",
    "/Users/kukkaii/Documents/DA PRoject/Clean_RoadData/Tambon/Processed_traffic_jam_index(Final)/road_combined_2024.csv"
]

# Display the Rows and Columns information
for file in files:
    # Read the CSV file
    df = pd.read_csv(file)
    
    # Get rows and columns count
    rows, columns = df.shape
    file_name = file.split("/")[-1]  # Extract file name from the path
    
    # Print the result
    print(f"{file_name}: Rows = {rows}, Columns = {columns}")
# Out:
# road_combined_2022.csv: Rows = 8313142, Columns = 4
# road_combined_2023.csv: Rows = 8713615, Columns = 4
# road_combined_2024.csv: Rows = 8263419, Columns = 4
